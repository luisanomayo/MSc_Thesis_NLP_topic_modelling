# %% [markdown]
# # **FEATURE EXTRACTION - TFIDF**

# %%
#import libraries
import pandas as pd
import numpy as np
import csv
import ast
import re
from prettytable import PrettyTable
from pprint import pprint

import time
import random

#data visualization libraries
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import plotly.io as pio
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator

#NLP & ML libraries
from gensim import corpora
from gensim.models import TfidfModel,LdaModel, CoherenceModel, LdaMulticore

from nltk import FreqDist

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

#vis
import pyLDAvis
import pyLDAvis.gensim_models

import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#set seed so that code output is deterministic
random.seed(2)  # Set the seed for Python's random module
np.random.seed(2)  # Set the seed for NumPy's random module

# %% [markdown]
# ## **CREATE CORPUS AND BOW REPRESENTATION**

# %%
#import cleaned data

def list_converter(text):
    #to revert list->str conversion from pd.read_csv
    return ast.literal_eval(text)


data = pd.read_csv('../Data/training_data.csv', converters ={'tokens':list_converter})
data = data.drop(columns = ['index'])
data.head()
# Out:
#   text_type       ID         date_created  year  \
# 0   comment  gtfou07  2021-04-05 13:13:23  2021
# 1   comment  gtfrgpe  2021-04-05 13:56:09  2021
# 2   comment  gthiiwi  2021-04-05 23:18:56  2021
# 3   comment  gtgfl4c  2021-04-05 18:21:42  2021
# 4   comment  gth5wdv  2021-04-05 21:42:41  2021
#
#                                            long_text  \
# 0  I am single and I have not traveled to any cun...
# 1       What happens when you shop at dragon mart...
# 2  That’s just absolutely hilarious, is this in t...
# 3             Is reel cinema and roxy part of emaar?
# 4  An innocent redditor here...can someone pls ex...
#
#                       clean_text                              tokens  \
# 0             single travel past              [single, travel, past]
# 1               shop dragon mart                [shop, dragon, mart]
# 2          hilarious spring souk           [hilarious, spring, souk]
# 3         reel cinema roxy emaar         [reel, cinema, roxy, emaar]
# 4  innocent pls explain everyday  [innocent, pls, explain, everyday]
#
#    word_count
# 0           3
# 1           3
# 2           3
# 3           4
# 4           4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65987 entries, 0 to 65986
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text_type     65987 non-null  object
#  1   ID            65987 non-null  object
#  2   date_created  65987 non-null  object
#  3   year          65987 non-null  int64
#  4   long_text     65987 non-null  object
#  5   clean_text    65987 non-null  object
#  6   tokens        65987 non-null  object
#  7   word_count    65987 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 4.0+ MB

# %%
#convert df['tokens'] to list of strings for bag-of-words model
docs = data['tokens'].tolist()

docs[0:5]
# Out:
# [['single', 'travel', 'past'],
#  ['shop', 'dragon', 'mart'],
#  ['hilarious', 'spring', 'souk'],
#  ['reel', 'cinema', 'roxy', 'emaar'],
#  ['innocent', 'pls', 'explain', 'everyday']]

# %%
#check number of unique words

unique_words = set([word for text in docs for word in text])

print (f'There are {len(unique_words)} unique words in the dataset')
# Out:
# There are 7577 unique words in the dataset

# %%
# Compute bigrams.
from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)

# %%
print(docs[200])
# Out:
# ['labor', 'law', 'common', 'blatant', 'sale', 'promotional', 'hire', 'filter', 'rife', 'real', 'estate', 'industry', 'young', 'motivation', 'law', 'align', 'progressive', 'practice', 'nature', 'labor_law', 'real_estate']

# %%
#from gensim bag of words documentation page

# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=50, no_above=0.75)

# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]

print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 2524
# Number of documents: 65987

# %% [markdown]
# ## **CONVERT TO TFIDF MODEL**

# %%
tfidf = TfidfModel (corpus)
tfidf_corpus = tfidf[corpus]

# %% [markdown]
# ## **TRAIN LDA MODEL**

# %%
#from gensim documentation at https://radimrehurek.com/gensim/auto_examples/tutorials/run_lda.html#sphx-glr-auto-examples-tutorials-run-lda-py
#https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/?expand_article=1#9createbigramandtrigrammodels
#https://github.com/clevyclev/Deep-Learning-Projects/blob/master/Latent%20Dirichlet%20Allocation%20-%20Bag%20of%20Words%20and%20TF-IDF/Latent_dirichlet_allocation.py

#training parameters

chunksize = 2000
passes = 10
iterations = 400
eval_every = None
id2word = dictionary.id2token
temp = dictionary[0] #to "load" the dictionary

#range of topics
topics_range = range (2,20,2)

#list to hold coherence value
model_coherence = []

for num_topics in topics_range:
    
    #train LDA model
    lda_model = LdaModel(corpus = tfidf_corpus,
                             id2word = dictionary,
                             chunksize = chunksize,
                             alpha = 'auto',
                             eta = 'auto',
                             passes = passes,
                             #iterations = iterations,
                             num_topics = num_topics,
                             per_word_topics = True,
                             random_state = 50,
                            )
    #compute coherence score
    coherence_model_lda = CoherenceModel (model = lda_model, texts = docs, dictionary = dictionary, coherence = 'c_v' )
    coherence_lda = coherence_model_lda.get_coherence()
    model_coherence.append(coherence_lda)

#plot coherence scores

plt.plot(topics_range, model_coherence)
plt.xlabel('number of topics')
plt.ylabel('coherence score')
plt.title('Coherence Score vs. Number of Topics')

plt.show()

# %%
#from gensim documentation at https://radimrehurek.com/gensim/auto_examples/tutorials/run_lda.html#sphx-glr-auto-examples-tutorials-run-lda-py
#https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/?expand_article=1#9createbigramandtrigrammodels
#https://github.com/clevyclev/Deep-Learning-Projects/blob/master/Latent%20Dirichlet%20Allocation%20-%20Bag%20of%20Words%20and%20TF-IDF/Latent_dirichlet_allocation.py

#training parameters
num_topics = 6
chunksize = 5000
passes = 10
iterations = 400
eval_every = None
id2word = dictionary.id2token
temp = dictionary[0] #to "load" the dictionary




    
#train LDA model
lda_model = LdaModel(corpus = corpus,
                             id2word = dictionary,
                             chunksize = chunksize,
                             alpha = 'auto',
                             eta = 'auto',
                             passes = passes,
                             #iterations = iterations,
                             num_topics = num_topics,
                             per_word_topics = True,
                             random_state = 20,
                            )

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.023*"arab" + 0.022*"indian" + 0.014*"movie" + 0.013*"cat" + 0.013*"play" '
#   '+ 0.012*"hire" + 0.012*"game" + 0.011*"nationality" + 0.011*"dog" + '
#   '0.009*"south"'),
#  (1,
#   '0.033*"drive" + 0.028*"fine" + 0.025*"police" + 0.022*"road" + 0.020*"stop" '
#   '+ 0.018*"lane" + 0.017*"driver" + 0.013*"fast" + 0.011*"speed" + '
#   '0.010*"light"'),
#  (2,
#   '0.016*"family" + 0.012*"test" + 0.011*"law" + 0.010*"school" + '
#   '0.009*"culture" + 0.008*"passport" + 0.008*"rule" + 0.008*"muslim" + '
#   '0.008*"arabic" + 0.007*"wife"'),
#  (3,
#   '0.024*"visa" + 0.019*"price" + 0.018*"card" + 0.018*"buy" + 0.016*"offer" + '
#   '0.015*"salary" + 0.015*"cost" + 0.015*"bank" + 0.013*"rent" + '
#   '0.012*"service"'),
#  (4,
#   '0.017*"food" + 0.013*"order" + 0.012*"water" + 0.012*"area" + '
#   '0.011*"restaurant" + 0.011*"tip" + 0.010*"buy" + 0.010*"delivery" + '
#   '0.010*"walk" + 0.009*"night"'),
#  (5,
#   '0.011*"local" + 0.009*"real" + 0.008*"government" + 0.008*"travel" + '
#   '0.007*"india" + 0.007*"covid" + 0.006*"build" + 0.006*"middle" + '
#   '0.006*"social" + 0.006*"expat"')]

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

#number of topics
num_topics = lda_model.num_topics

# Number of words to display for each topic
num_words = 10

#define color map
colors = cm.viridis(np.linspace(0,1, num_topics))

#subplot layout
rows = 3
cols = int(np.ceil(num_topics/rows))

plt.figure(figsize=(15,10))


# Iterate through the topics
for topic_num in range(num_topics):
    # top words and their probabilities for each topic
    top_words = lda_model.show_topic(topic_num, topn=num_words)
    
    # Separate the words and probabilities
    topic_words, probs = zip(*top_words)
    
    #create subplot
    plt.subplot(rows, cols, topic_num +1)
    
    # Plot the words and probabilities as a horizontal bar chart
    plt.barh(topic_words, probs, color = colors[topic_num])
    plt.xlabel('Probability')
    plt.title(f'Topic {topic_num}')
    plt.gca().invert_yaxis()  # Invert y-axis to have the highest probability at the top

plt.tight_layout()
plt.show()

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary, sort_topics = False)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el339051090532809560342718" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el339051090532809560342718_data = {"mdsDat": {"x": [0.40301961699076394, -0.04757898081656232, 0.02278310004033449, -0.1347684031520846, -0.20445993678638988, -0.03899539627606221], "y": [0.0270401831482859, -0.38435241119397834, 0.04407740413956807, 0.22775580528923248, -0.02319853073687184, 0.10867754935376349], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [8.111442789547358, 12.706506872038803, 21.269247384898204, 14.857506488555567, 19.453030791995243, 23.602265672964826]}, "tinfo": {"Term": ["drive", "fine", "visa", "police", "road", "food", "buy", "price", "card", "family", "stop", "arab", "lane", "indian", "driver", "cost", "bank", "order", "test", "offer", "salary", "law", "water", "rent", "area", "local", "service", "fast", "restaurant", "tip", "arab", "indian", "movie", "cat", "game", "dog", "wage", "pro", "burj", "pet", "european", "british", "interview", "israel", "female", "oman", "music", "united_arab", "khalifa", "asian", "animal", "indians", "south", "color", "belong", "male", "african", "racist", "film", "chip", "united", "play", "nationality", "racism", "hire", "living", "gcc", "peace", "drive", "fine", "police", "road", "lane", "speed", "driver", "light", "traffic", "vehicle", "limit", "sheikh", "taxi", "camera", "left", "rta", "seat", "bus", "ride", "flash", "survey", "accident", "driving", "fast", "exit", "distance", "dangerous", "red", "patrol", "bin", "transport", "line", "catch", "plate", "airport", "pass", "stop", "hit", "metro", "turn", "parking", "park", "fly", "file", "test", "school", "muslim", "parent", "wife", "child", "respect", "sector", "treat", "death", "father", "religion", "positive", "friday", "coronavirus", "prayer", "recovery", "amp", "crypto", "practice", "society", "teach", "respectful", "scene", "pray", "jail", "mom", "mother", "husband", "marry", "law", "private", "young", "family", "age", "dad", "employee", "culture", "emirati", "worker", "arabic", "passport", "rule", "force", "date", "hospital", "western", "result", "employer", "common", "covid", "meet", "visa", "card", "bank", "rent", "property", "website", "credit", "fee", "insurance", "contract", "cancel", "email", "sale", "payment", "credit_card", "loan", "monthly", "aed", "agent", "landlord", "dubaicentral", "code", "permit", "register", "golden", "budget", "debt", "application", "transfer", "golden_visa", "charge", "cash", "cost", "price", "advance", "offer", "process", "salary", "sell", "buy", "service", "apply", "customer", "plan", "apartment", "food", "water", "restaurant", "tip", "delivery", "mall", "building", "eat", "shop", "noon", "beach", "store", "order", "drink", "amazon", "station", "room", "etisalat", "deliver", "taste", "chicken", "burger", "hot", "cool", "marina", "shawarma", "heat", "alcohol", "hair", "item", "clean", "night", "area", "hotel", "walk", "inside", "door", "morning", "cheap", "brand", "buy", "house", "outside", "visit", "citizenship", "university", "project", "pandemic", "expo", "mask", "opportunity", "industry", "economy", "real", "student", "study", "india", "east", "degree", "virus", "marketing", "tech", "civil", "rich", "middle_east", "pakistan", "career", "restriction", "economic", "lockdown", "graduate", "wonderful", "protect", "field", "build", "vaccine", "research", "middle", "local", "class", "social", "government", "travel", "spread", "europe", "management", "land", "resident", "community", "term", "canada", "expat", "market", "covid", "safe", "plan", "health", "risk"], "Freq": [2545.0, 2173.0, 2143.0, 1896.0, 1661.0, 1984.0, 2761.0, 1820.0, 1594.0, 2027.0, 1835.0, 1126.0, 1345.0, 1071.0, 1267.0, 1427.0, 1309.0, 1513.0, 1587.0, 1517.0, 1573.0, 1478.0, 1366.0, 1171.0, 1403.0, 1568.0, 1660.0, 997.0, 1245.0, 1241.0, 1125.3880505391737, 1070.4738629350204, 694.5121699728446, 658.0171929147792, 584.6239463686348, 541.2861354530949, 425.60548120212496, 398.05961836161293, 379.6378533108217, 373.05653687233456, 365.02939357992807, 349.29793252697885, 337.323098 ...

# %%
#dictionary.save('../topic_modelling/bow_model.dict')
#print ('gensim dictionary created')
