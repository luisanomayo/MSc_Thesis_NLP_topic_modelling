# %% [markdown]
# # **FEATURE EXTRACTION - TFIDF**

# %%
#import libraries
import pandas as pd
import numpy as np
import csv
import ast
import re
from prettytable import PrettyTable
from pprint import pprint

import time
import random

#data visualization libraries
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import plotly.io as pio
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator

#NLP & ML libraries
from gensim import corpora
from gensim.models import TfidfModel,LdaModel, CoherenceModel, LdaMulticore

from nltk import FreqDist

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

#vis
import pyLDAvis
import pyLDAvis.gensim_models

import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
#set seed so that code output is deterministic
random.seed(2)  # Set the seed for Python's random module
np.random.seed(2)  # Set the seed for NumPy's random module

# %% [markdown]
# ## **CREATE CORPUS AND BOW REPRESENTATION**

# %%
#import cleaned data

def list_converter(text):
    #to revert list->str conversion from pd.read_csv
    return ast.literal_eval(text)


data = pd.read_csv('../Data/training_data.csv', converters ={'tokens':list_converter})
data = data.drop(columns = ['index'])
data.head()
# Out:
#   text_type       ID         date_created  year  \
# 0   comment  gtfou07  2021-04-05 13:13:23  2021
# 1   comment  gtfrgpe  2021-04-05 13:56:09  2021
# 2   comment  gthiiwi  2021-04-05 23:18:56  2021
# 3   comment  gtgfl4c  2021-04-05 18:21:42  2021
# 4   comment  gth5wdv  2021-04-05 21:42:41  2021
#
#                                            long_text  \
# 0  I am single and I have not traveled to any cun...
# 1       What happens when you shop at dragon mart...
# 2  That’s just absolutely hilarious, is this in t...
# 3             Is reel cinema and roxy part of emaar?
# 4  An innocent redditor here...can someone pls ex...
#
#                       clean_text                              tokens  \
# 0             single travel past              [single, travel, past]
# 1               shop dragon mart                [shop, dragon, mart]
# 2          hilarious spring souk           [hilarious, spring, souk]
# 3         reel cinema roxy emaar         [reel, cinema, roxy, emaar]
# 4  innocent pls explain everyday  [innocent, pls, explain, everyday]
#
#    word_count
# 0           3
# 1           3
# 2           3
# 3           4
# 4           4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65987 entries, 0 to 65986
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text_type     65987 non-null  object
#  1   ID            65987 non-null  object
#  2   date_created  65987 non-null  object
#  3   year          65987 non-null  int64
#  4   long_text     65987 non-null  object
#  5   clean_text    65987 non-null  object
#  6   tokens        65987 non-null  object
#  7   word_count    65987 non-null  int64
# dtypes: int64(2), object(6)
# memory usage: 4.0+ MB

# %%
#convert df['tokens'] to list of strings for bag-of-words model
docs = data['tokens'].tolist()

docs[0:5]
# Out:
# [['single', 'travel', 'past'],
#  ['shop', 'dragon', 'mart'],
#  ['hilarious', 'spring', 'souk'],
#  ['reel', 'cinema', 'roxy', 'emaar'],
#  ['innocent', 'pls', 'explain', 'everyday']]

# %%
#check number of unique words

unique_words = set([word for text in docs for word in text])

print (f'There are {len(unique_words)} unique words in the dataset')
# Out:
# There are 7577 unique words in the dataset

# %%
# Compute bigrams.
from gensim.models import Phrases

# Add bigrams and trigrams to docs (only ones that appear 20 times or more).
bigram = Phrases(docs, min_count=20)
for idx in range(len(docs)):
    for token in bigram[docs[idx]]:
        if '_' in token:
            # Token is a bigram, add to document.
            docs[idx].append(token)

# %%
print(docs[200])
# Out:
# ['labor', 'law', 'common', 'blatant', 'sale', 'promotional', 'hire', 'filter', 'rife', 'real', 'estate', 'industry', 'young', 'motivation', 'law', 'align', 'progressive', 'practice', 'nature', 'labor_law', 'real_estate']

# %%
#from gensim bag of words documentation page

# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(docs)

# Filter out words that occur less than 20 documents, or more than 50% of the documents.
dictionary.filter_extremes () #(no_below=50, no_above=0.75)

# Bag-of-words representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs]

print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 7836
# Number of documents: 65987

# %% [markdown]
# ## **CONVERT TO TFIDF MODEL**

# %%
tfidf = TfidfModel (corpus)
tfidf_corpus = tfidf[corpus]

# %% [markdown]
# ## **TRAIN LDA MODEL**

# %%
#from gensim documentation at https://radimrehurek.com/gensim/auto_examples/tutorials/run_lda.html#sphx-glr-auto-examples-tutorials-run-lda-py
#https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/?expand_article=1#9createbigramandtrigrammodels
#https://github.com/clevyclev/Deep-Learning-Projects/blob/master/Latent%20Dirichlet%20Allocation%20-%20Bag%20of%20Words%20and%20TF-IDF/Latent_dirichlet_allocation.py

#training parameters

chunksize = 2000
passes = 20
iterations = 400
eval_every = None
id2word = dictionary.id2token
temp = dictionary[0] #to "load" the dictionary

#range of topics
topics_range = range (2,20,2)

#list to hold coherence value
model_coherence = []

for num_topics in topics_range:
    
    #train LDA model
    lda_model = LdaModel(corpus = tfidf_corpus,
                             id2word = dictionary,
                             chunksize = chunksize,
                             alpha = 'auto',
                             eta = 'auto',
                             passes = passes,
                             iterations = iterations,
                             num_topics = num_topics,
                             per_word_topics = True,
                             random_state = 50,
                            )
    #compute coherence score
    coherence_model_lda = CoherenceModel (model = lda_model, texts = docs, dictionary = dictionary, coherence = 'c_v' )
    coherence_lda = coherence_model_lda.get_coherence()
    model_coherence.append(coherence_lda)

#plot coherence scores

plt.plot(topics_range, model_coherence)
plt.xlabel('number of topics')
plt.ylabel('coherence score')
plt.title('Coherence Score vs. Number of Topics')

plt.show()

# %%
#from gensim documentation at https://radimrehurek.com/gensim/auto_examples/tutorials/run_lda.html#sphx-glr-auto-examples-tutorials-run-lda-py
#https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/?expand_article=1#9createbigramandtrigrammodels
#https://github.com/clevyclev/Deep-Learning-Projects/blob/master/Latent%20Dirichlet%20Allocation%20-%20Bag%20of%20Words%20and%20TF-IDF/Latent_dirichlet_allocation.py

#training parameters
num_topics = 8
chunksize = 5000
passes = 10
iterations = 400
eval_every = None
id2word = dictionary.id2token
temp = dictionary[0] #to "load" the dictionary




    
#train LDA model
lda_model = LdaModel(corpus = corpus,
                             id2word = dictionary,
                             chunksize = chunksize,
                             alpha = 'auto',
                             eta = 'auto',
                             passes = passes,
                             #iterations = iterations,
                             num_topics = num_topics,
                             per_word_topics = True,
                             random_state = 20,
                            )

# %%
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
# Out:
# [(0,
#   '0.039*"card" + 0.022*"arab" + 0.020*"arabic" + 0.018*"credit" + '
#   '0.014*"station" + 0.013*"citizenship" + 0.012*"credit_card" + '
#   '0.012*"language" + 0.012*"canada" + 0.011*"tax"'),
#  (1,
#   '0.033*"covid" + 0.028*"test" + 0.014*"health" + 0.014*"insurance" + '
#   '0.013*"medical" + 0.012*"vaccine" + 0.011*"mask" + 0.011*"result" + '
#   '0.010*"fly" + 0.010*"flight"'),
#  (2,
#   '0.030*"police" + 0.016*"stop" + 0.011*"movie" + 0.010*"cat" + 0.010*"play" '
#   '+ 0.009*"game" + 0.008*"dog" + 0.008*"street" + 0.008*"complaint" + '
#   '0.008*"file"'),
#  (3,
#   '0.012*"local" + 0.011*"law" + 0.010*"government" + 0.009*"travel" + '
#   '0.008*"expat" + 0.008*"rule" + 0.008*"apply" + 0.008*"culture" + '
#   '0.008*"india" + 0.007*"muslim"'),
#  (4,
#   '0.025*"visa" + 0.017*"family" + 0.012*"school" + 0.010*"indian" + '
#   '0.009*"meet" + 0.008*"passport" + 0.008*"wife" + 0.008*"parent" + '
#   '0.007*"date" + 0.007*"child"'),
#  (5,
#   '0.025*"buy" + 0.023*"food" + 0.021*"service" + 0.020*"price" + '
#   '0.017*"order" + 0.016*"water" + 0.014*"restaurant" + 0.014*"tip" + '
#   '0.013*"delivery" + 0.012*"sell"'),
#  (6,
#   '0.043*"drive" + 0.036*"fine" + 0.028*"road" + 0.023*"lane" + 0.022*"driver" '
#   '+ 0.017*"fast" + 0.016*"middle" + 0.014*"speed" + 0.013*"light" + '
#   '0.013*"pass"'),
#  (7,
#   '0.014*"salary" + 0.013*"bank" + 0.012*"plan" + 0.012*"area" + 0.012*"rent" '
#   '+ 0.011*"real" + 0.011*"cost" + 0.010*"property" + 0.010*"market" + '
#   '0.010*"visit"')]

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm

#number of topics
num_topics = lda_model.num_topics

# Number of words to display for each topic
num_words = 10

#define color map
colors = cm.viridis(np.linspace(0,1, num_topics))

#subplot layout
rows = 3
cols = int(np.ceil(num_topics/rows))

plt.figure(figsize=(15,10))


# Iterate through the topics
for topic_num in range(num_topics):
    # top words and their probabilities for each topic
    top_words = lda_model.show_topic(topic_num, topn=num_words)
    
    # Separate the words and probabilities
    topic_words, probs = zip(*top_words)
    
    #create subplot
    plt.subplot(rows, cols, topic_num +1)
    
    # Plot the words and probabilities as a horizontal bar chart
    plt.barh(topic_words, probs, color = colors[topic_num])
    plt.xlabel('Probability')
    plt.title(f'Topic {topic_num}')
    plt.gca().invert_yaxis()  # Invert y-axis to have the highest probability at the top

plt.tight_layout()
plt.show()

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, dictionary)#, sort_topics = False)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el33905183557968565513677" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el33905183557968565513677_data = {"mdsDat": {"x": [0.1441704377245756, 0.22028589043204205, 0.11719673651000477, 0.1901676035899677, -0.14858276580691898, -0.14837164205697567, -0.1537453530355098, -0.22112090735718531], "y": [-0.03319971214065368, 0.01025801582535965, 0.010515774365117013, 0.08143863860792153, -0.20530455038245182, -0.2472596400725136, 0.05087199502128265, 0.33267947877593806], "topics": [1, 2, 3, 4, 5, 6, 7, 8], "cluster": [1, 1, 1, 1, 1, 1, 1, 1], "Freq": [19.96988290166647, 17.015703918662336, 16.152620691982587, 12.89482445144835, 9.802413720097773, 9.151375901012166, 7.601819038237544, 7.411359376892773]}, "tinfo": {"Term": ["drive", "fine", "card", "visa", "police", "buy", "covid", "road", "food", "service", "test", "price", "lane", "family", "driver", "order", "arab", "water", "local", "arabic", "bank", "restaurant", "tip", "fast", "salary", "area", "school", "credit", "middle", "delivery", "law", "government", "muslim", "employee", "legal", "private", "expat", "sector", "party", "weekend", "religion", "saudi", "permit", "friday", "illegal", "prayer", "letter", "gcc", "court", "restriction", "mosque", "discuss", "emiratis", "practice", "pray", "policy", "crime", "individual", "resource", "islamic", "local", "etisalat", "national", "record", "rule", "regard", "majority", "internet", "form", "pandemic", "airport", "employer", "india", "western", "social", "travel", "culture", "contract", "emirati", "apply", "worker", "authority", "safe", "resident", "morning", "community", "sign", "public", "bank", "rent", "property", "market", "mall", "building", "apartment", "hotel", "beach", "area", "room", "project", "expo", "estate", "agent", "spot", "landlord", "investment", "real_estate", "marina", "invest", "budget", "villa", "survey", "platform", "trade", "rental", "transfer", "club", "fund", "real", "advance", "park", "plan", "sale", "build", "book", "fee", "parking", "salary", "house", "night", "suggestion", "walk", "payment", "spend", "cost", "visit", "offer", "space", "buy", "visa", "wife", "parent", "child", "student", "treat", "dubaicentral", "young", "south", "degree", "golden", "dad", "bear", "digital", "golden_visa", "career", "raise", "school", "graduate", "mom", "engineer", "nationality", "struggle", "husband", "marry", "guard", "asian", "sponsor", "racism", "indians", "indian", "fun", "university", "teach", "meet", "age", "racist", "family", "security", "moment", "folk", "date", "manager", "poor", "passport", "cool", "study", "summer", "hire", "couple", "hot", "super", "food", "order", "water", "restaurant", "tip", "delivery", "eat", "customer", "store", "noon", "product", "drink", "amazon", "brand", "deliver", "taste", "chicken", "burger", "scam", "discount", "bill", "shawarma", "shop", "hair", "dirham", "item", "refund", "box", "oil", "dhs", "service", "charge", "clean", "price", "buy", "sell", "cheap", "aed", "movie", "cat", "game", "dog", "file", "amp", "die", "pet", "delete", "israel", "copy", "repair", "animal", "officer", "fight", "bin", "loud", "police", "nissan", "film", "stare", "war", "attack", "qatar", "youtube", "mars", "sunny", "con", "sticker", "mission", "pro", "eye", "peace", "play", "hide", "lady", "street", "facebook", "ruin", "complaint", "user", "win", "catch", "window", "stop", "rest", "pull", "hit", "plate", "ban", "drive", "road", "lane", "middle", "speed", "light", "traffic", "limit", "vehicle", "pass", "east", "taxi", "camera", "rta", "left", "bus", "ride", "flash", "civil", "driver", "middle_east", "accident", "burj", "driving", "khalifa", "exit", "software", "dangerous", "bike", "left_lane", "fast", "seat", "fine", "class", "line", "red", "license", "turn", "stop", "covid", "test", "health", "insurance", "medical", "vaccine", "mask", "hospital", "death", "spread", "doctor", "virus", "coronavirus", "june", "recovery", "eid", "damage", "lockdown", "energy", "flight", "renewal", "testing", "certificate", "active", "mental", "vat", "rain", "toilet", "symptom", "marc ...

# %%
#dictionary.save('../topic_modelling/bow_model.dict')
#print ('gensim dictionary created')
